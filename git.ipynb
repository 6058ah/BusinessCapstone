# %%
from os.path import join
from google.colab import drive

ROOT='/content/drive'
drive.mount(ROOT)
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# !ls /content/drive/'My Drive'/'경영캡스톤'
# Out:
# git.ipynb  주식데이터.ipynb

# %%
PROJ = "/drive/'My Drive'/'경영캡스톤"
PROJ_PATH=join(ROOT,PROJ)

# %%
import os
import sys

sys.path.insert(0, PROJ_PATH)

# %cd /content/drive/'My Drive'/'경영캡스톤'
# Out:
# /content/drive/My Drive/경영캡스톤

# %%
# !pwd
# Out:
# /content/drive/My Drive/경영캡스톤

# %%
# !git clone https://github.com/6058ah/BusinessCapstone.git
